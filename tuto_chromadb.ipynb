# %%
import chromadb
chroma_client = chromadb.Client()
collection = chroma_client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This document is about Mumbai",
        "This document is about Pune"
    ],
    ids = ['id1', 'id2']
)
# Out:
# C:\Users\Manal\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|█████| 79.3M/79.3M [00:35<00:00, 2.35MiB/s]

# %%
all_documents = collection.get()
all_documents
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about Mumbai', 'This document is about Pune'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
documents = collection.get(ids=["id1"])
documents
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['This document is about Mumbai'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
results = collection.query(
    query_texts=["Query is about cst staion"], 
        n_results=2 # how many results to return
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about Mumbai',
#    'This document is about Pune']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.5393619537353516, 1.6197999715805054]]}

# %%
collection.delete(ids=all_documents['ids'])
collection.get()
# Out:
# {'ids': [],
#  'embeddings': None,
#  'documents': [],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': []}
